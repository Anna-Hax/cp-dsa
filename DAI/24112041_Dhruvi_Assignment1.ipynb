# %%
def outer():
    x = "local"
    def inner():
        nonlocal x
        x = "modified"
    inner()
    return x

print(outer())
# Out:
# modified

# %%
numbers = [1, 2, 3, 4, 5]
cubes = list(map(lambda x: x**3, numbers))
print(cubes)
# Out:
# [1, 8, 27, 64, 125]

# %%
letter = "D"
height = 5
width = 5

for i in range(height):
    for j in range(width):
        if j == 0:
            print("*", end=" ")
        elif (i == 0 or i == height - 1) and j < width - 1:
            print("*", end=" ")
        elif j == width - 1 and i not in (0, height - 1):
            print("*", end=" ")
        else:
            print(" ", end=" ")
    print()
# Out:
# * * * *
# *       *
# *       *
# *       *
# * * * *
